# %%
import sys 
sys.path.append('..')
from src.dino_v1 import get_image_features, define_model, feature_dim

# %%
import torchvision.transforms.functional as FT
import torch

# %%
sys.path.append('..')
from cifar.cifarRawCorrupted import get_corrupt_loaders

# %%
c_loader = get_corrupt_loaders(model_name='dino')
# Out:
# (50000, 32, 32, 3)

# %%
im_batch = next(iter(c_loader))

# %%
u, l = im_batch

# %%
m, s = [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]

# %%
den = (u[-3]*torch.tensor(s)[:, None, None])+torch.tensor(m)[:, None, None]

# %%
FT.to_pil_image(den)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
device = 'cuda:0'

# %%
model = define_model(device=device)
# Out:
# Using cache found in /home/omoussa/.cache/torch/hub/facebookresearch_dino_main

# %%
im_features = get_image_features(model, im_batch[0].to(device))

# %%
im_features
# Out:
# torch.Size([64, 768])

# %%
sample = torch.randn(1, 3, 224, 224)

# %%
vitb16(sample).shape
# Out:
# torch.Size([1, 768])
